# %% [markdown]
# <a href="https://colab.research.google.com/github/SyedShabaaz/SyedShabaaz/blob/main/Uber%20Mock_interview%20Ques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **For the given cab pick up data set, can you find how many drivers didn't meet any other drivers at the airport? we consider two drivers met each other if they are at the airport at the same time i.e difference between two drivers "Request timestamp" is less than 5min.**

# %%
import numpy as np
import pandas as pd
from datetime import datetime
df = pd.read_csv("Uber.csv")

# %%
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %%
mask = ~df['Request timestamp'].isna()
mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 6740    True
# 6741    True
# 6742    True
# 6743    True
# 6744    True
# Name: Request timestamp, Length: 6745, dtype: bool

# %%
df = df.loc[mask]
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# ...

# %% [markdown]
# For the given cab pick up data set, can you find how many drivers didn't meet any other drivers at the airport?
# we consider two drivers met each other if they are at the airport at the same time i.e difference between two drivers "Request timestamp" is less than 5min.

# %%
df = df[df['Pickup point']=='Airport']

# %%
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 5           3879      Airport        1.0     Trip Completed
# 6           4270      Airport        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6734        6732      Airport        NaN  No Cars Available
# 6735        6737      Airport        NaN  No Cars Available
# 6736        6744      Airport        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#        Request timestamp       Drop timestamp       time_diff
# 0    2016-11-07 11:51:00      11/7/2016 13:00             NaT
# 1    2016-11-07 17:57:00      11/7/2016 18:47 0 days 06:06:00
# ...

# %%
df.dropna(axis = 0,how = "any",inplace=True)
# Out:
# <ipython-input-51-194454eb1ca9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis = 0,how = "any",inplace=True)

# %%
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'])
df['Request timestamp'].dt.time
# Out:
# <ipython-input-52-e3371a1b065b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request timestamp'] = pd.to_datetime(df['Request timestamp'])
# 231     00:34:03
# 1263    00:44:02
# 1165    01:04:42
# 2075    01:17:55
# 1006    01:22:32
#           ...
# 245     23:35:00
# 2179    23:35:00
# 133     23:43:00
# 1789    23:53:00
# 2120    23:54:00
# Name: Request timestamp, Length: 1325, dtype: object

# %%
df.sort_values(by=['Request timestamp'], inplace=True)
# Out:
# <ipython-input-53-9e34f707017e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['Request timestamp'], inplace=True)

# %%
df
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 231         2689      Airport       24.0  Trip Completed 2016-07-13 00:34:03
# 1263        2691      Airport      131.0  Trip Completed 2016-07-13 00:44:02
# 1165        2701      Airport      121.0  Trip Completed 2016-07-13 01:04:42
# 2075        2707      Airport      219.0  Trip Completed 2016-07-13 01:17:55
# 1006        2708      Airport      105.0  Trip Completed 2016-07-13 01:22:32
# ...          ...          ...        ...             ...                 ...
# 245         2667      Airport       25.0  Trip Completed 2016-12-07 23:35:00
# 2179        2668      Airport      228.0  Trip Completed 2016-12-07 23:35:00
# 133         2675      Airport       15.0  Trip Completed 2016-12-07 23:43:00
# 1789        2676      Airport      188.0  Trip Completed 2016-12-07 23:53:00
# 2120        2679      Airport      223.0  Trip Completed 2016-12-07 23:54:00
#
#            Drop timestamp       time_diff
# ...

# %%
df['Request timestamp'].dt.time
# Out:
# 231     00:34:03
# 1263    00:44:02
# 1165    01:04:42
# 2075    01:17:55
# 1006    01:22:32
#           ...
# 245     23:35:00
# 2179    23:35:00
# 133     23:43:00
# 1789    23:53:00
# 2120    23:54:00
# Name: Request timestamp, Length: 1325, dtype: object

# %%
isinstance(df,pd.DataFrame)
# Out:
# True

# %%
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'])

# calculate the time difference between consecutive rows
df['time_diff'] = df['Request timestamp'].diff()

df
# Out:
# <ipython-input-56-cc4164781913>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request timestamp'] = pd.to_datetime(df['Request timestamp'])
# <ipython-input-56-cc4164781913>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['time_diff'] = df['Request timestamp'].diff()
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 231         2689      Airport       24.0  Trip Completed 2016-07-13 00:34:03
# ...

# %%
df[df['time_diff'] > pd.Timedelta(minutes=5)]
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 1263        2691      Airport      131.0  Trip Completed 2016-07-13 00:44:02
# 1165        2701      Airport      121.0  Trip Completed 2016-07-13 01:04:42
# 2075        2707      Airport      219.0  Trip Completed 2016-07-13 01:17:55
# 2054        2709      Airport      216.0  Trip Completed 2016-07-13 01:27:34
# 1804        2714      Airport      190.0  Trip Completed 2016-07-13 01:52:50
# ...          ...          ...        ...             ...                 ...
# 2270        2650      Airport      237.0  Trip Completed 2016-12-07 22:54:00
# 2792        2657      Airport      296.0  Trip Completed 2016-12-07 23:11:00
# 1526        2658      Airport      161.0  Trip Completed 2016-12-07 23:18:00
# 133         2675      Airport       15.0  Trip Completed 2016-12-07 23:43:00
# 1789        2676      Airport      188.0  Trip Completed 2016-12-07 23:53:00
#
#            Drop timestamp       time_diff
# ...

# %%
# prompt: find the difference which is greater than 5 mins from time_diff column

df[df['time_diff'] > pd.Timedelta(minutes=5)].shape[0]
# Out:
# 458

# %%
df.sort_values(by=['Drop timestamp'])
# Out:
#       Request id Pickup point  Driver id          Status   Request timestamp  \
# 2700           1      Airport      285.0  Trip Completed 2016-11-07 00:20:00
# 1058         469      Airport      110.0  Trip Completed 2016-11-07 09:24:00
# 1572         500      Airport      167.0  Trip Completed 2016-11-07 09:38:00
# 364          488      Airport       37.0  Trip Completed 2016-11-07 09:35:00
# 2073         475      Airport      219.0  Trip Completed 2016-11-07 09:24:00
# ...          ...          ...        ...             ...                 ...
# 623         6749      Airport       65.0  Trip Completed 2016-07-15 23:48:42
# 131         6733      Airport       14.0  Trip Completed 2016-07-15 23:32:44
# 2607        6750      Airport      274.0  Trip Completed 2016-07-15 23:51:42
# 801         6748      Airport       81.0  Trip Completed 2016-07-15 23:45:24
# 1095        6755      Airport      113.0  Trip Completed 2016-07-15 23:57:32
#
#            Drop timestamp       time_diff
# ...

# %%
df['less_than5'] = df[df['time_diff'].apply(lambda x:x['time_diff'] > 5)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a7b5690c694e> in <cell line: 1>()
# ----> 1 df['less_than5'] = df[df['time_diff'].apply(lambda x:x['time_diff'] > 5)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# ...

# %%
# call datetime.strptime to convert
# it into datetime datatype
datetime_obj = datetime.strptime(['Request timestamp'].str(),
                                 "%d%b%Y%H%M%S")

# It will print the datetime object
print(datetime_obj)

# extract the time from datetime_obj
time = datetime_obj.time()


# it will print time that
# we have extracted from datetime obj
print(time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-2287fdd891ca> in <cell line: 3>()
#       1 # call datetime.strptime to convert
#       2 # it into datetime datatype
# ----> 3 datetime_obj = datetime.strptime(['Request timestamp'].str(),
#       4                                  "%d%b%Y%H%M%S")
#       5
#
# AttributeError: 'list' object has no attribute 'str'

# %%
df[df['Pickup point'] == 'Airport'].groupby(['Driver id'])['Request timestamp'].diff() > 300
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#    1053         try:
# -> 1054             other = self._validate_comparison_value(other)
#    1055         except InvalidComparison:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     587         elif not is_list_like(other):
# --> 588             raise InvalidComparison(other)
#     589
#
# InvalidComparison: 300
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4a64c65496c0> in <cell line: 1>()
# ----> 1 df[df['Pickup point'] == 'Airport'].groupby(['Driver id'])['Request timestamp'].diff() > 300
#
# ...

# %%
df = df[df['Request timestamp'].diff().total_seconds() > 300]

# Count the number of rows remaining.
count = df.shape[0]

# Print the number of drivers who didn't meet any other drivers at the airport.
print(count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5a411e70ffeb> in <cell line: 1>()
# ----> 1 df = df[df['Request timestamp'].diff().total_seconds() > 300]
#       2
#       3 # Count the number of rows remaining.
#       4 count = df.shape[0]
#       5
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'total_seconds'
